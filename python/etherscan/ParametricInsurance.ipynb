# %%
from fetch_ParametricInsurance import *
from decode_ParametricInsurance import *
from smart_contract import *
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Transaction Analysis

# %%
import pandas as pd
transactions_df = pd.DataFrame(transactions['result'])
transactions_df
# Out:
#    blockNumber                                          blockHash   timeStamp  \
# 0      7143345  0xf8d9aa8b95e09baf420c97ee392004e89b60858fdf0a...  1732457004
# 1      7150103  0x2f9668c212629a55b9bb5c301f23bf695773e59fe8b8...  1732543368
# 2      7150106  0x5e0c3ce90d3561b6cacf317f93a097f89890950cf1ca...  1732543416
# 3      7150126  0x356572489fd6e5b983fb3208e0e96493400e6bdefd13...  1732543656
# 4      7150138  0x74712ac58e5ad12179f852a565fc63080de732eb78ab...  1732543812
# 5      7150163  0x5c956d728a9ccc0074f4fc7f1aad57d7bd3176cab80b...  1732544136
# 6      7150167  0x5bebba279c36cbd1586437d15a436784da37e0c3c04f...  1732544184
# 7      7150190  0xb665c11ec81b25bdc09c6f2b3ad4b9678dbfab1f0deb...  1732544484
# 8      7150198  0xb21d2aede9ccc5369d04ecc432f05a286f63afa355d8...  1732544592
# 9      7150205  0xc5d4ab4ec293596503d7260eee05ec17c5edd8afadb8...  1732544676
# 10     7150215  0x55cab9701e60d51f8aa06248b8ebe8364bc60fa3534e...  1732544796
# 11     7150225  0xd7edc448dc18ccb3272c2a32bbbbe7acd8edf019eca3...  1732544916
# 12     7150275  0x31b7527dbd3fd3c843e62793c61b83bc09a46fec2a0e...  1732545540
# 13     7150281  0x288e450749bfa7f46445eeae5e38467e9eea965ad998...  1732545612
# 14     7150304  0xec57602b12edb419b30ab28a5dc4c6dbe78be00b95bd...  1732545900
# 15     7150308  0x390fe89f2a34a91e9d3a7a232b08eb9f6593c7aac52f...  1732545960
# 16     7150319  0xfebe412cb5385ff88f1436f1d981001649cbc29fe471...  1732546116
# 17     7150347  0xa4de0e05eea8bfa9aa6e20bd966a935a2ca228b007fd...  1732546464
#
#                                                  hash nonce transactionIndex  \
# 0   0x93cf6496705ee18fc6fe687b91c5095da71b635e4ff5...    65               10
# 1   0x090e7b72d347fe42387e3a1ed9beaaa7e51e300b30cf...    39               16
# 2   0x897f8f07b49aa9711f6efda87143d5b7b9500a37223a...    66               10
# 3   0x949143deb8061e74a25391e6e0d4f8c34b95f2a6d52d...    29               17
# 4   0x0403189418f1f3c0c2b71b71653c7d693a70de43e48f...    30               11
# 5   0x23692668235ac6134bd5d139e6d8def8c29f5475e227...    67               14
# 6   0xe32c40643d09563f6eb2ba11b503860b511089afd39b...    31               22
# 7   0x56ed2b9063aabf91903b5f99486bf228e490985e1606...    68               58
# 8   0x448730c2298c86cf4633bd3b550c7b6bb9ee70a58120...    69               25
# 9   0xdcb288d2a6187944d7314efac9bcd131688deca8027d...    70                8
# 10  0xb045914ce2237bbfa67f856218cb54f7367b9306ad8b...    32               13
# 11  0x09a30c5128406c609645afffded032e63ea2efecce6a...    40               14
# 12  0xdc438416e01379593a0db4676790ce07586d4510d699...    71               29
# 15                1   120710         44134       0
# 16                1    51711         44123       0
# 17                1   239551         44095       0

# %%
import pandas as pd

def generate_transaction_table_latex(df):
    """
    Generate LaTeX table code for the transactions DataFrame.

    Parameters:
    - df: pandas DataFrame (extracted transactions data).

    Returns:
    - str: LaTeX code for the table.
    """
    # Start LaTeX table
    latex_table = r"""
\begin{table}[h!]
\centering
\begin{tabular}{|l|l|l|l|}
\hline
\textbf{Variable Name} & \textbf{Type} & \textbf{Example Value} & \textbf{Description} \\ \hline
"""

    # Add rows for each column in the DataFrame
    for col in df.columns:
        col_type = df[col].dtype
        example_value = df[col].iloc[0] if not df[col].empty else "N/A"
        description = "Description not provided"  # Default description
        # Add the row to the LaTeX table
        latex_table += f"{col} & {col_type} & {str(example_value)} & {description} \\\\ \\hline\n"

    # End LaTeX table
    latex_table += r"""
\end{tabular}
\caption{Description of the transactions associated with the contract.}
\label{tab:transactions}
\end{table}
"""
    return latex_table

# Example: Assume transactions_df is already populated
# transactions_df = pd.DataFrame(transactions['result'])

# Generate LaTeX code for the transactions DataFrame
latex_code = generate_transaction_table_latex(transactions_df)
from IPython.display import display, Markdown

# Display the LaTeX code as markdown
display(Markdown(f"```\n{latex_code}\n```"))
# Out:
# ```
#
# \begin{table}[h!]
# \centering
# \begin{tabular}{|l|l|l|l|}
# \hline
# \textbf{Variable Name} & \textbf{Type} & \textbf{Example Value} & \textbf{Description} \\ \hline
# blockNumber & object & 7143345 & Description not provided \\ \hline
# blockHash & object & 0xf8d9aa8b95e09baf420c97ee392004e89b60858fdf0ab3fcedecc24d5a0da0b0 & Description not provided \\ \hline
# timeStamp & object & 1732457004 & Description not provided \\ \hline
# hash & object & 0x93cf6496705ee18fc6fe687b91c5095da71b635e4ff5ab21d18e607f2b8f5419 & Description not provided \\ \hline
# nonce & object & 65 & Description not provided \\ \hline
# transactionIndex & object & 10 & Description not provided \\ \hline
# from & object & 0xe8e79b8b8c0481fa33a8e0fca902ad5754bfe1c3 & Description not provided \\ \hline
# to & object &  & Description not provided \\ \hline
# value & object & 0 & Description not provided \\ \hline
# gas & object & 2935995 & Description not provided \\ \hline
# gasPrice & object & 12145467087 & Description not provided \\ \hline
# input & object & ... & Description not provided \\ \hline
# methodId & object & 0x60806040 & Description not provided \\ \hline
# functionName & object &  & Description not provided \\ \hline
# contractAddress & object & 0xa4f3a8567e1d712fc8a53b3a1b6ec76dd42cc10b & Description not provided \\ \hline
# cumulativeGasUsed & object & 3655764 & Description not provided \\ \hline
# txreceipt_status & object & 1 & Description not provided \\ \hline
# gasUsed & object & 2911719 & Description not provided \\ \hline
# confirmations & object & 51097 & Description not provided \\ \hline
# isError & object & 0 & Description not provided \\ \hline
#
# \end{tabular}
# \caption{Description of the transactions associated with the contract.}
# \label{tab:transactions}
# \end{table}
#
# ```

# %% [markdown]
# ## Cost of the transactions

# %%
plt.figure(figsize=(12, 7))
transaction_costs = np.array([int(transactions_df.iloc[k]["gasUsed"]) * int(transactions_df.iloc[k]["gasPrice"]) / 1e18 for k in range(len(transactions_df))])
plt.scatter(np.arange(1, len(transaction_costs) +1 , 1), transaction_costs)
# Add custom x-axis labels
plt.xlabel("Transaction #", fontsize=16)
plt.title("Transaction cost (in ETH) ", fontsize=16)

# Add custom x-axis labels
plt.xticks(np.arange(1, len(transaction_costs) +1 , 1), np.arange(1, len(transaction_costs) +1 , 1), fontsize=16)
plt.yticks(fontsize=16)
# Adjust layout to fit everything nicely
plt.tight_layout()
sns.despine()
plt.savefig("../../figures/transaction_cost.pdf")
np.sum(transaction_costs)
# Out:
# 0.08875661582483606

# %% [markdown]
# # Event log analysis

# %% [markdown]
# Construction of the stochastic processes:
# - $X_t$
# - $B_t$
# - $SCR_t$
# - $MCR_t$
# - $Y_t^{(i)}$ $i = 1, 2 ,3$
# - $Z_t$ be the vector of the ETH balance of the addresses of the owner, surplus provider and policyholder

# %%
addresses = np.array(transactions_df['from'])

Xt, Bt, SCRt, MCRt, rt, eta1t, eta2t, sn, mu, qSCR, qMCR = [0], [0], [0], [0], [1], [0.1], [0.05], [0], [0], [2.5758], [1.0364]
Zt = {"0xE8e79B8B8c0481fa33a8E0fcA902ad5754BfE1C3".lower(): [0.4366],
    "0x2CF8ed1664616483c12Ef3113f6F62E68f1a810A".lower(): [0.2],
    "0xd34a37613A382bA503f1599F514C9788dF3659C4".lower():[0.21] 
    
    }

address_role = {"0xE8e79B8B8c0481fa33a8E0fcA902ad5754BfE1C3".lower(): "Owner",
    "0x2CF8ed1664616483c12Ef3113f6F62E68f1a810A".lower(): "Surplus Provider",
    "0xd34a37613A382bA503f1599F514C9788dF3659C4".lower(): "Policyholder",
    }

Yt = {}
for address in np.unique(addresses):
    Yt[address]= [0]
Y = [0]

PTF = []
event_names = []
liquidation = True

# %%
for decoded_event in decoded_events:
    event_names.append(decoded_event["event"])
    print(decoded_event)
    if decoded_event["event"] == "Fund": 
        x, y = decoded_event["x"] / 10**18, decoded_event["y"] / 10**18
        Xt.append(Xt[-1] + x)
        Bt.append(Bt[-1] + x)
        SCRt.append(SCRt[-1])
        MCRt.append(MCRt[-1])
        rt.append(rt[-1])
        eta1t.append(eta1t[-1])
        eta2t.append(eta2t[-1])
        sn.append(sn[-1])
        mu.append(mu[-1])
        qSCR.append(qSCR[-1])
        qMCR.append(qMCR[-1])
        for address in np.unique(addresses):
            if address == decoded_event["investor_address"]:
                Yt[address].append(Yt[address][-1] + y)
                Zt[address].append(Zt[address][-1] - x)
            
            else:
                Yt[address].append(Yt[address][-1])
                Zt[address].append(Zt[address][-1])
        Y.append(Y[-1] + y)

    elif decoded_event["event"] == "InsuranceUnderwritten": 
        p = get_random_number(decoded_event["EventDescription"])
        l = decoded_event["payoutAmount"] / 10**18
        eta = eta1t[-1] + eta2t[-1]
        cp = (1 + eta) * p * l
        sn.append(sn[-1] + l**2 * p * (1-p)), mu.append(mu[-1] + (l * p) * (eta))
        Xt.append(Xt[-1])
        Bt.append(Bt[-1] + cp)
        SCRt.append(np.sqrt(sn[-1]) * qSCR[-1]  - mu[-1])
        MCRt.append(np.sqrt(sn[-1]) * qMCR[-1]  - mu[-1])
        print(SCRt[-1])
        y = p * l * eta2t[-1] / rt[-1]
        
        for address in np.unique(addresses):
            if address == decoded_event["customer_address"]:
                Yt[address].append(Yt[address][-1] + y)
                Zt[address].append(Zt[address][-1] - cp)
            else:
                Yt[address].append(Yt[address][-1])
                Zt[address].append(Zt[address][-1])
        Y.append(Y[-1] + y)
        rt.append( Xt[-1] / Y[-1])
        PTF.append({"address":decoded_event["customer_address"], "l": l, "p": p, "eta1": eta1t[-1], "eta2": eta2t[-1], "status": 0})


    elif decoded_event["event"] == "ParametersUpdated":
        Xt.append(Xt[-1])
        Bt.append(Bt[-1])
        rt.append(rt[-1])
        sn.append(sn[-1])
        mu.append(mu[-1])
        for address in np.unique(addresses):
            Yt[address].append(Yt[address][-1])
            Zt[address].append(Zt[address][-1])
        Y.append(Y[-1])
        eta1t.append(decoded_event["eta1"] / 10**4)
        eta2t.append(decoded_event["eta2"] / 10**4)
        qSCR.append(decoded_event["qAlphaSCR"] / 10**4)
        qMCR.append(decoded_event["qAlphaMCR"] / 10**4)
        SCRt.append(np.sqrt(sn[-1]) * qSCR[-1] - mu[-1])
        MCRt.append(np.sqrt(sn[-1]) * qMCR[-1] - mu[-1])
        print(SCRt[-1])
        

    elif decoded_event["event"] == "ClaimSettled":
        policy = PTF[decoded_event["contractId"] -1]
        p, l, eta = policy["p"], policy["l"], policy["eta1"] + policy["eta2"]
        cp = (1 + eta) * p * l
        sn.append(sn[-1] - l**2 * p * (1-p)), mu.append(mu[-1] - (l * p) * (eta))
        SCRt.append(np.sqrt(sn[-1]) * qSCR[-1] - mu[-1])
        MCRt.append(np.sqrt(sn[-1]) * qMCR[-1] - mu[-1])
        if decoded_event["payoutTransfered"]:
            Xt.append(Xt[-1] - l + cp)
            Bt.append(Bt[-1] - l)
            PTF[decoded_event["contractId"] -1]["status"] = 1
        else:
            Xt.append(Xt[-1] + cp)
            Bt.append(Bt[-1])
            PTF[decoded_event["contractId"] -1]["status"] = 2
        for address in np.unique(addresses):
            Yt[address].append(Yt[address][-1])
            Zt[address].append(Zt[address][-1])
        Y.append(Y[-1])
        rt.append( Xt[-1] / Y[-1])
        
    elif decoded_event["event"] == "Burn":
        x = decoded_event["x"] / 10**18
        y = decoded_event["y"] / 10**18
        Xt.append(Xt[-1] - x)
        Bt.append(Bt[-1] - x)
        SCRt.append(SCRt[-1])
        MCRt.append(MCRt[-1])
        rt.append(rt[-1])
        eta1t.append(eta1t[-1])
        eta2t.append(eta2t[-1])
        sn.append(sn[-1])
        mu.append(mu[-1])
        qSCR.append(qSCR[-1])
        qMCR.append(qMCR[-1])
        for address in np.unique(addresses):
            if address == decoded_event["investor_address"]:
                Yt[address].append(Yt[address][-1] - y)
                Zt[address].append(Zt[address][-1] + x)
            
            else:
                Yt[address].append(Yt[address][-1])
                Zt[address].append(Zt[address][-1])
        Y.append(Y[-1] - y)
# Out:
# {'event': 'Fund', 'investor_address': '0x2cf8ed1664616483c12ef3113f6f62e68f1a810a', 'x': 100000000000000000, 'y': 100000000000000000}
# {'event': 'Fund', 'investor_address': '0xe8e79b8b8c0481fa33a8e0fca902ad5754bfe1c3', 'x': 80000000000000000, 'y': 80000000000000000}
# {'event': 'InsuranceUnderwritten', 'contractId': 1, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'EventDescription': 'rain', 'payoutAmount': 60000000000000000, 'status': 0}
# 0.06321413568417138
# {'event': 'InsuranceUnderwritten', 'contractId': 2, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'EventDescription': 'hail', 'payoutAmount': 10000000000000000, 'status': 0}
# 0.06331201595644605
# {'event': 'ParametersUpdated', 'eta1': 250, 'eta2': 250, 'qAlphaSCR': 25758, 'qAlphaMCR': 10364}
# 0.06331201595644605
# {'event': 'InsuranceUnderwritten', 'contractId': 3, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'EventDescription': 'snow', 'payoutAmount': 100000000000000000, 'status': 0}
# 0.13708917011366806
# {'event': 'ClaimSettled', 'contractId': 2, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'payoutTransfered': False, 'Xt': 180362250000000000}
# {'event': 'Burn', 'investor_address': '0xe8e79b8b8c0481fa33a8e0fca902ad5754bfe1c3', 'x': 9828000000000000, 'y': 10000000000000000}
# {'event': 'ClaimSettled', 'contractId': 3, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'payoutTransfered': True, 'Xt': 126478250000000000}
# {'event': 'InsuranceUnderwritten', 'contractId': 4, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'EventDescription': 'sun', 'payoutAmount': 80000000000000000, 'status': 0}
# 0.11511833493415544
# {'event': 'Burn', 'investor_address': '0x2cf8ed1664616483c12ef3113f6f62e68f1a810a', 'x': 11353888000000000, 'y': 15680000000000000}
# {'event': 'ParametersUpdated', 'eta1': 250, 'eta2': 250, 'qAlphaSCR': 25758, 'qAlphaMCR': 21701}
# 0.11511833493415544
# {'event': 'ClaimSettled', 'contractId': 4, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'payoutTransfered': True, 'Xt': 70303562000000000}
# {'event': 'InsuranceUnderwritten', 'contractId': 5, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'EventDescription': 'wind', 'payoutAmount': 20000000000000000, 'status': 0}
# 0.0673353760085677
# {'event': 'ParametersUpdated', 'eta1': 250, 'eta2': 250, 'qAlphaSCR': 23263, 'qAlphaMCR': 21701}
# 0.06014169413725095
# {'event': 'Burn', 'investor_address': '0xe8e79b8b8c0481fa33a8e0fca902ad5754bfe1c3', 'x': 10151424000000000, 'y': 23040000000000000}
# {'event': 'ClaimSettled', 'contractId': 5, 'customer_address': '0xd34a37613a382ba503f1599f514c9788df3659c4', 'payoutTransfered': True, 'Xt': 50305638000000000}

# %%
if liquidation:
    event_names.append("Refund")
    # Refund
    total_refund = 0
    total_redistribution = 0
    refunded_addresses = []
    for policy in PTF:
        if policy["status"] == 0:
            refunded_addresses.append(policy["address"])
            l, p, eta1, eta2 = policy["l"], policy["p"], policy["eta1"], policy["eta2"]
            total_refund += p * l * (1 + eta1)
            Zt[policy["address"]].append(Zt[policy["address"]][-1] + p * l * (1 + eta1))
            policy["status"] = 3
    for address in np.unique(addresses):
        Yt[address].append(Yt[address][-1])
        if address not in refunded_addresses:
            Zt[address].append(Zt[address][-1])
    Bt.append(Bt[-1] - total_refund)
    Xt.append(Bt[-1])
    Y.append(Y[-1])
    rt.append(Xt[-1] / Y[-1])
    SCRt.append(0)
    MCRt.append(0)   
    # Redistribution 
    event_names.append("Redistribute")
    for address in list(Yt.keys()):
        x = Yt[address][-1] * rt[-1]
        total_redistribution += x
        Zt[address].append(Zt[address][-1] + x)                                  
        Yt[address].append(0)
    Y.append(0)
    Xt.append(0)
    Bt.append(Bt[-1] - total_redistribution)
    rt.append(1)
    SCRt.append(0)
    MCRt.append(0)

# %% [markdown]
# # Plot of the account balances

# %%
event_names
dict_event_names = {
    "Fund": "Fund",
    "InsuranceUnderwritten": "Underwrite",
    "ParametersUpdated": "Update",
    "ClaimSettled": "Settle",
    "Burn": "Burn",
    "Refund": "Refund",
    "Redistribute": "Redistribute",
}
event_names_short = [dict_event_names[event] for event in event_names]

# %%
plt.figure(figsize=(12, 7))
plt.step(np.arange(1, len(Bt)+1, 1), Bt, label="Smart contract") 
# plt.scatter(np.arange(1, len(Bt) + 1), Bt, zorder=3)
for address in list(Zt.keys()):
    plt.step(np.arange(1, len(Zt[address])+1, 1), Zt[address], label=address_role[address])
plt.ylabel("Balance", fontsize=16)

# Add custom x-axis labels
plt.xticks(np.arange(1, len(event_names_short) + 1), event_names_short, rotation=45, fontsize=14)
plt.yticks(fontsize=16)

plt.legend(fontsize=16, loc='upper center', bbox_to_anchor=(0.5, 1.20), ncol=4)

# Adjust layout to fit everything nicely
plt.tight_layout()
sns.despine()
plt.savefig("../../figures/balance.pdf")

# %%
plt.figure(figsize=(12, 7))
plt.step(np.arange(1, len(Bt)+1, 1), Bt, label="Smart contract balance") 
plt.step(np.arange(1, len(Bt)+1, 1), Xt, label="Surplus")
plt.step(np.arange(1, len(Bt)+1, 1), SCRt, label="SCR")
plt.step(np.arange(1, len(Bt)+1, 1), MCRt, label="MCR")
plt.ylabel("ETH", fontsize=16)

# Add custom x-axis labels
plt.xticks(np.arange(1, len(event_names_short) + 1), event_names_short, rotation=45, fontsize=14)
plt.yticks(fontsize=16)
plt.legend(fontsize=16, loc='upper center', bbox_to_anchor=(0.5, 1.20), ncol=4)

# Adjust layout to fit everything nicely
plt.tight_layout()
sns.despine()
plt.savefig("../../figures/surplus.pdf")
